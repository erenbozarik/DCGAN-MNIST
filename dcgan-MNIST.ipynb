# %% [markdown]
# ## Generative Adverserial Networks
# by Eren BOZARIK

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import math
import numpy as np
import os
from PIL import Image

from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Activation, Reshape
from tensorflow.python.keras.layers import BatchNormalization
from tensorflow.python.keras.layers import UpSampling2D, Conv2D
from tensorflow.python.keras.layers import ELU
from tensorflow.python.keras.layers import Flatten, Dropout
from tensorflow.python.keras.optimizers import Adam
from tensorflow.python.keras.datasets import mnist

# %% [markdown]
# ## Helper

# %%
def combine_images(generated_images):
    total,width,height = generated_images.shape[:-1]
    cols = int(math.sqrt(total))
    rows = math.ceil(float(total)/cols)
    combined_image = np.zeros((height*rows, width*cols),
                              dtype=generated_images.dtype)

    for index, image in enumerate(generated_images):
        i = int(index/cols)
        j = index % cols
        combined_image[width*i:width*(i+1), height*j:height*(j+1)] = image[:, :, 0]
    return combined_image

def show_progress(epoch, batch, g_loss, d_loss, g_acc, d_acc):
    msg = "epoch: {}, batch: {}, g_loss: {}, d_loss: {}, g_accuracy: {}, d_accuracy: {}"
    print(msg.format(epoch, batch, g_loss, d_loss, g_acc, d_acc))

# %% [markdown]
# ## Generator

# %%
def generator(input_dim=100, units=1024, activation='relu'): 
    model = Sequential() 
    model.add(Dense(input_dim=input_dim, units=units)) 
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(Dense(128*7*7)) 
    model.add(BatchNormalization())
    model.add(Activation(activation)) 
    model.add(Reshape((7, 7, 128), input_shape=(128*7*7,))) 
    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(64, (5, 5), padding='same')) 
    model.add(BatchNormalization())
    model.add(Activation(activation))
    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(1, (5, 5), padding='same'))
    model.add(Activation('tanh'))
    print(model.summary())
    return model

# %% [markdown]
# ## Discriminator

# %%
def discriminator(input_shape=(28, 28, 1), nb_filter=64): 
    model = Sequential()    . Cikan sonuc 1'e yakinda resim gercektir. 0'a yakinsa sahte. 
    model.add(Conv2D(nb_filter, (5, 5), strides=(2, 2), padding='same', input_shape=input_shape)) 
    model.add(BatchNormalization())
    model.add(ELU())
    model.add(Conv2D(2*nb_filter, (5, 5), strides=(2, 2)))
    model.add(BatchNormalization())
    model.add(ELU())
    model.add(Flatten())
    model.add(Dense(4*nb_filter))
    model.add(BatchNormalization())
    model.add(ELU())
    model.add(Dropout(0.5))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    print(model.summary())
    return model

# %%
batch_size = 32
num_epoch = 50
learning_rate = 0.0002
image_path = '/content/drive/My Drive/dcgandeepart/images/'

if not os.path.exists(image_path):
    os.mkdir(image_path)

# %% [markdown]
# ## Train Function

# %%
def train():
    (x_train, y_train), (_, _) = mnist.load_data()
    x_train = (x_train.astype(np.float32) - 127.5) / 127.5
    x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)

    g = generator()
    d= discriminator()

    optimize = Adam(lr=learning_rate, beta_1=0.5)
    d.trainable = True
    d.compile(loss='binary_crossentropy',
              metrics=['accuracy'],
              optimizer=optimize)

    d.trainable = False
    dcgan = Sequential([g, d])
    dcgan.compile(loss='binary_crossentropy',
                  metrics=['accuracy'],
                  optimizer=optimize)

    num_batches = x_train.shape[0] // batch_size
    gen_img = np.array([np.random.uniform(-1, 1, 100) for _ in range(49)])
    y_d_true = [1] * batch_size
    y_d_gen = [0] * batch_size
    y_g = [1] * batch_size

    for epoch in range(num_epoch):
        for i in range(num_batches):
            x_d_batch = x_train[i*batch_size:(i+1)*batch_size]
            x_g = np.array([np.random.normal(0, 0.5, 100) for _ in range(batch_size)])
            x_d_gen = g.predict(x_g)

            d_loss = d.train_on_batch(x_d_batch, y_d_true)
            d_loss = d.train_on_batch(x_d_gen, y_d_gen)

            g_loss = dcgan.train_on_batch(x_g, y_g)
            show_progress(epoch, i, g_loss[0], d_loss[0], g_loss[1], d_loss[1])

        image = combine_images(g.predict(gen_img))
        image = image * 127.5 + 127.5
        Image.fromarray(image.astype(np.uint8)).save(image_path + "%03d.png" % (epoch))

# %% [markdown]
# **Egitim esnasında aşağıda alınan uyarıyı umursamayınız. GANs standart sinir ağlarından biraz farklı olduğu için keras uyarı veriyor. Uyarıya rağmen model eğitiliyor.**
#
#
# ```
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after?
# ```

# %%
if __name__ == '__main__':
    train()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 1024)              103424
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 1024)              4096
# _________________________________________________________________
# activation_10 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 6272)              6428800
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 6272)              25088
# _________________________________________________________________
# activation_11 (Activation)   (None, 6272)              0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_12 (Activation)   (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 1)         1601
# _________________________________________________________________
# activation_13 (Activation)   (None, 28, 28, 1)         0
# =================================================================
# Total params: 6,768,129
# Trainable params: 6,753,409
# Non-trainable params: 14,720
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 14, 14, 64)        1664
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 14, 14, 64)        256
# _________________________________________________________________
# elu_6 (ELU)                  (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 128)         204928
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 5, 5, 128)         512
# _________________________________________________________________
# elu_7 (ELU)                  (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               819456
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# elu_8 (ELU)                  (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 257
# _________________________________________________________________
# activation_14 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 1,028,097
# Trainable params: 1,027,201
# Non-trainable params: 896
# _________________________________________________________________
# None
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 0, g_loss: 0.9393985271453857, d_loss: 0.9837862253189087, g_accuracy: 0.40625, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1, g_loss: 0.896169126033783, d_loss: 1.0288972854614258, g_accuracy: 0.53125, d_accuracy: 0.375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 2, g_loss: 0.8626545071601868, d_loss: 0.8713210225105286, g_accuracy: 0.4375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 3, g_loss: 1.0528916120529175, d_loss: 0.9886295795440674, g_accuracy: 0.40625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 4, g_loss: 0.8148012161254883, d_loss: 0.856613278388977, g_accuracy: 0.59375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 5, g_loss: 0.7492450475692749, d_loss: 0.8670680522918701, g_accuracy: 0.59375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 6, g_loss: 1.0860950946807861, d_loss: 0.8142919540405273, g_accuracy: 0.375, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 7, g_loss: 0.693513035774231, d_loss: 0.8628770112991333, g_accuracy: 0.59375, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 8, g_loss: 0.9953803420066833, d_loss: 0.7434380650520325, g_accuracy: 0.46875, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 9, g_loss: 0.736202597618103, d_loss: 0.8597700595855713, g_accuracy: 0.59375, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 10, g_loss: 0.8894859552383423, d_loss: 0.9049286842346191, g_accuracy: 0.375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 11, g_loss: 1.10555100440979, d_loss: 0.9703960418701172, g_accuracy: 0.34375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 12, g_loss: 1.0633502006530762, d_loss: 1.0769591331481934, g_accuracy: 0.375, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 13, g_loss: 0.8676831722259521, d_loss: 1.0259696245193481, g_accuracy: 0.46875, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 14, g_loss: 0.8336825370788574, d_loss: 0.8391945958137512, g_accuracy: 0.46875, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 15, g_loss: 0.8535228967666626, d_loss: 0.7701776027679443, g_accuracy: 0.4375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 16, g_loss: 1.0391888618469238, d_loss: 0.7522160410881042, g_accuracy: 0.375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 17, g_loss: 0.8787437677383423, d_loss: 0.8395576477050781, g_accuracy: 0.53125, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 18, g_loss: 0.843593955039978, d_loss: 0.861935019493103, g_accuracy: 0.5625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 19, g_loss: 0.9371128082275391, d_loss: 1.205660104751587, g_accuracy: 0.46875, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 20, g_loss: 0.7187541723251343, d_loss: 0.9541736841201782, g_accuracy: 0.53125, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 21, g_loss: 0.9448200464248657, d_loss: 0.7106791734695435, g_accuracy: 0.46875, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 22, g_loss: 0.8650821447372437, d_loss: 0.9429290294647217, g_accuracy: 0.625, d_accuracy: 0.34375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 23, g_loss: 1.0224592685699463, d_loss: 0.8050657510757446, g_accuracy: 0.375, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 24, g_loss: 0.9086610078811646, d_loss: 0.804153323173523, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 25, g_loss: 0.8068902492523193, d_loss: 0.7947678565979004, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 26, g_loss: 0.8385736346244812, d_loss: 1.0136750936508179, g_accuracy: 0.46875, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 27, g_loss: 0.9754079580307007, d_loss: 1.1594812870025635, g_accuracy: 0.5, d_accuracy: 0.3125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 28, g_loss: 0.6519066095352173, d_loss: 0.7829166650772095, g_accuracy: 0.6875, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 29, g_loss: 0.9622781872749329, d_loss: 0.8783958554267883, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 30, g_loss: 0.6610238552093506, d_loss: 0.8838841319084167, g_accuracy: 0.6875, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 31, g_loss: 0.7475341558456421, d_loss: 0.8665751814842224, g_accuracy: 0.59375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 32, g_loss: 0.8417180776596069, d_loss: 0.8805517554283142, g_accuracy: 0.5, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 33, g_loss: 0.8270237445831299, d_loss: 0.838927149772644, g_accuracy: 0.53125, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 34, g_loss: 0.7158516645431519, d_loss: 0.8011049032211304, g_accuracy: 0.625, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 35, g_loss: 0.7483034133911133, d_loss: 0.8427263498306274, g_accuracy: 0.59375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 36, g_loss: 0.7193033695220947, d_loss: 0.800144374370575, g_accuracy: 0.46875, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 37, g_loss: 0.9457577466964722, d_loss: 0.874504566192627, g_accuracy: 0.5625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 38, g_loss: 0.7152180075645447, d_loss: 0.9746596813201904, g_accuracy: 0.5625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 39, g_loss: 0.8680830597877502, d_loss: 0.8724265098571777, g_accuracy: 0.53125, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 40, g_loss: 0.7302429676055908, d_loss: 1.0279465913772583, g_accuracy: 0.5625, d_accuracy: 0.375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 41, g_loss: 0.9485458731651306, d_loss: 0.8344111442565918, g_accuracy: 0.4375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 42, g_loss: 0.9265961647033691, d_loss: 0.8653080463409424, g_accuracy: 0.40625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 43, g_loss: 0.830157995223999, d_loss: 0.9177578687667847, g_accuracy: 0.53125, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 44, g_loss: 0.7218431830406189, d_loss: 0.9171819686889648, g_accuracy: 0.5625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 45, g_loss: 1.0296738147735596, d_loss: 0.8396975994110107, g_accuracy: 0.40625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 46, g_loss: 0.9998311996459961, d_loss: 0.8610889315605164, g_accuracy: 0.46875, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 47, g_loss: 0.9366582036018372, d_loss: 0.8572834730148315, g_accuracy: 0.53125, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 48, g_loss: 0.8972147703170776, d_loss: 0.8236364126205444, g_accuracy: 0.375, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 49, g_loss: 0.8401901721954346, d_loss: 1.1026474237442017, g_accuracy: 0.375, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 50, g_loss: 0.7756449580192566, d_loss: 0.6837053298950195, g_accuracy: 0.59375, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 51, g_loss: 0.8637862801551819, d_loss: 0.8242686986923218, g_accuracy: 0.46875, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 52, g_loss: 0.9321297407150269, d_loss: 0.7638067603111267, g_accuracy: 0.40625, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 53, g_loss: 0.7895320653915405, d_loss: 1.194109320640564, g_accuracy: 0.5625, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 54, g_loss: 1.048848271369934, d_loss: 0.7859070897102356, g_accuracy: 0.34375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 55, g_loss: 0.7604271173477173, d_loss: 0.9525976181030273, g_accuracy: 0.46875, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 56, g_loss: 0.975750207901001, d_loss: 0.8891043066978455, g_accuracy: 0.4375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 57, g_loss: 0.8161753416061401, d_loss: 0.793077290058136, g_accuracy: 0.5, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 58, g_loss: 0.880084753036499, d_loss: 0.7863204479217529, g_accuracy: 0.53125, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 59, g_loss: 0.7251327037811279, d_loss: 0.8916633129119873, g_accuracy: 0.5625, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 60, g_loss: 0.8004686832427979, d_loss: 0.7393618822097778, g_accuracy: 0.5, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 61, g_loss: 0.9591673612594604, d_loss: 0.9650071263313293, g_accuracy: 0.375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 62, g_loss: 0.9108486175537109, d_loss: 0.8156642913818359, g_accuracy: 0.4375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 63, g_loss: 0.854532778263092, d_loss: 0.9701161980628967, g_accuracy: 0.40625, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 64, g_loss: 0.7738634347915649, d_loss: 0.9410150051116943, g_accuracy: 0.5625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 65, g_loss: 0.6652219295501709, d_loss: 0.7683422565460205, g_accuracy: 0.59375, d_accuracy: 0.75
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 66, g_loss: 0.9927951097488403, d_loss: 0.7253795862197876, g_accuracy: 0.375, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 67, g_loss: 0.8641315698623657, d_loss: 0.8326708078384399, g_accuracy: 0.59375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 68, g_loss: 0.7547991275787354, d_loss: 0.8680237531661987, g_accuracy: 0.53125, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 69, g_loss: 0.8641170263290405, d_loss: 0.8096663355827332, g_accuracy: 0.4375, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 70, g_loss: 0.8217997550964355, d_loss: 0.7463146448135376, g_accuracy: 0.5, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 71, g_loss: 0.7214673161506653, d_loss: 0.7178676724433899, g_accuracy: 0.65625, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 72, g_loss: 0.8557603359222412, d_loss: 0.9270362854003906, g_accuracy: 0.5, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 73, g_loss: 0.6916019916534424, d_loss: 0.843529999256134, g_accuracy: 0.5625, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 74, g_loss: 0.730330228805542, d_loss: 0.8175266981124878, g_accuracy: 0.65625, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 75, g_loss: 0.929478645324707, d_loss: 0.909220814704895, g_accuracy: 0.46875, d_accuracy: 0.375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 76, g_loss: 0.6869813203811646, d_loss: 0.7795012593269348, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 77, g_loss: 0.8378815650939941, d_loss: 0.8463791608810425, g_accuracy: 0.53125, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 78, g_loss: 0.9232807159423828, d_loss: 0.7853633165359497, g_accuracy: 0.40625, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 79, g_loss: 0.9012243151664734, d_loss: 0.8032167553901672, g_accuracy: 0.5, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 80, g_loss: 1.0950820446014404, d_loss: 0.9614207744598389, g_accuracy: 0.34375, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 81, g_loss: 0.8346543312072754, d_loss: 0.900683581829071, g_accuracy: 0.5, d_accuracy: 0.40625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 82, g_loss: 0.7834641933441162, d_loss: 0.9001762866973877, g_accuracy: 0.5, d_accuracy: 0.3125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 83, g_loss: 0.8964880704879761, d_loss: 0.8560819029808044, g_accuracy: 0.5625, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 84, g_loss: 0.8990025520324707, d_loss: 0.7134070992469788, g_accuracy: 0.4375, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 85, g_loss: 0.8445471525192261, d_loss: 0.742064356803894, g_accuracy: 0.53125, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 86, g_loss: 0.9206607937812805, d_loss: 0.9027069807052612, g_accuracy: 0.5, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 87, g_loss: 0.9434595704078674, d_loss: 0.6667535901069641, g_accuracy: 0.4375, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 88, g_loss: 0.9562152624130249, d_loss: 0.853744387626648, g_accuracy: 0.34375, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 89, g_loss: 0.8279143571853638, d_loss: 0.6255580186843872, g_accuracy: 0.46875, d_accuracy: 0.6875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 90, g_loss: 0.784328281879425, d_loss: 0.6813797950744629, g_accuracy: 0.5625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 91, g_loss: 0.8904122114181519, d_loss: 0.7762702107429504, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 92, g_loss: 0.8602491617202759, d_loss: 0.7267361283302307, g_accuracy: 0.5625, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 93, g_loss: 0.797467827796936, d_loss: 0.7209030389785767, g_accuracy: 0.6875, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 94, g_loss: 0.8426123857498169, d_loss: 0.7239710688591003, g_accuracy: 0.53125, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 95, g_loss: 0.8765079975128174, d_loss: 0.7589319944381714, g_accuracy: 0.46875, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 96, g_loss: 0.6987271308898926, d_loss: 0.8801817893981934, g_accuracy: 0.5625, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 97, g_loss: 0.7853857278823853, d_loss: 0.7833138704299927, g_accuracy: 0.5, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 98, g_loss: 0.9353391528129578, d_loss: 0.7826521396636963, g_accuracy: 0.5, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 99, g_loss: 0.9693858027458191, d_loss: 0.8452553749084473, g_accuracy: 0.4375, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# ...
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1486, g_loss: 0.6867117881774902, d_loss: 0.702293872833252, g_accuracy: 0.59375, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1487, g_loss: 0.7920324802398682, d_loss: 0.721526026725769, g_accuracy: 0.46875, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1488, g_loss: 0.8086802959442139, d_loss: 0.672808051109314, g_accuracy: 0.4375, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1489, g_loss: 0.8529446125030518, d_loss: 0.7706977128982544, g_accuracy: 0.34375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1490, g_loss: 0.7112523317337036, d_loss: 0.7840731143951416, g_accuracy: 0.53125, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1491, g_loss: 0.6975260972976685, d_loss: 0.7006478309631348, g_accuracy: 0.5625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1492, g_loss: 0.7560402154922485, d_loss: 0.6827178597450256, g_accuracy: 0.375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1493, g_loss: 0.7843117117881775, d_loss: 0.7516276240348816, g_accuracy: 0.5, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1494, g_loss: 0.7345479726791382, d_loss: 0.6575837731361389, g_accuracy: 0.46875, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1495, g_loss: 0.8529642820358276, d_loss: 0.6382585167884827, g_accuracy: 0.5, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1496, g_loss: 0.7428083419799805, d_loss: 0.6587240695953369, g_accuracy: 0.5, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1497, g_loss: 0.8177595138549805, d_loss: 0.7933173179626465, g_accuracy: 0.4375, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1498, g_loss: 0.8245294094085693, d_loss: 0.6364132165908813, g_accuracy: 0.34375, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1499, g_loss: 0.6822909116744995, d_loss: 0.7398492097854614, g_accuracy: 0.625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1500, g_loss: 0.7362876534461975, d_loss: 0.6836887001991272, g_accuracy: 0.46875, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1501, g_loss: 0.7993074059486389, d_loss: 0.6467220783233643, g_accuracy: 0.40625, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1502, g_loss: 0.7880033850669861, d_loss: 0.7540088891983032, g_accuracy: 0.375, d_accuracy: 0.46875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1503, g_loss: 0.866218090057373, d_loss: 0.6517442464828491, g_accuracy: 0.3125, d_accuracy: 0.59375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1504, g_loss: 0.716411828994751, d_loss: 0.6710965037345886, g_accuracy: 0.5625, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1505, g_loss: 0.8268108367919922, d_loss: 0.7585755586624146, g_accuracy: 0.375, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1506, g_loss: 0.7837811708450317, d_loss: 0.668663740158081, g_accuracy: 0.4375, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1507, g_loss: 0.7332457900047302, d_loss: 0.7324768304824829, g_accuracy: 0.5, d_accuracy: 0.5625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1508, g_loss: 0.7379987239837646, d_loss: 0.8058293461799622, g_accuracy: 0.4375, d_accuracy: 0.375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1509, g_loss: 0.7355417609214783, d_loss: 0.6645063161849976, g_accuracy: 0.4375, d_accuracy: 0.6875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1510, g_loss: 0.7831155061721802, d_loss: 0.7065117359161377, g_accuracy: 0.40625, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1511, g_loss: 0.7983304858207703, d_loss: 0.7867950201034546, g_accuracy: 0.53125, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1512, g_loss: 0.7359964847564697, d_loss: 0.750578761100769, g_accuracy: 0.40625, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1513, g_loss: 0.7430163025856018, d_loss: 0.6681761741638184, g_accuracy: 0.46875, d_accuracy: 0.4375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1514, g_loss: 0.7574926018714905, d_loss: 0.7225178480148315, g_accuracy: 0.4375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1515, g_loss: 0.770233690738678, d_loss: 0.6499786376953125, g_accuracy: 0.4375, d_accuracy: 0.6875
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1516, g_loss: 0.7856422662734985, d_loss: 0.7459940314292908, g_accuracy: 0.375, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1517, g_loss: 0.8234834671020508, d_loss: 0.7532135248184204, g_accuracy: 0.34375, d_accuracy: 0.375
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1518, g_loss: 0.7652487754821777, d_loss: 0.7575246095657349, g_accuracy: 0.5, d_accuracy: 0.5
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1519, g_loss: 0.7159631848335266, d_loss: 0.7344172596931458, g_accuracy: 0.53125, d_accuracy: 0.53125
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1520, g_loss: 0.8743821382522583, d_loss: 0.6007789373397827, g_accuracy: 0.34375, d_accuracy: 0.65625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# epoch: 0, batch: 1521, g_loss: 0.85943603515625, d_loss: 0.7026233673095703, g_accuracy: 0.46875, d_accuracy: 0.625
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
